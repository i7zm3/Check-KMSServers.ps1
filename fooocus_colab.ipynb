# %% [markdown]
# <a href="https://colab.research.google.com/github/i7zm3/Check-KMSServers.ps1/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Fooocus Server Setup
import os

# Install dependencies
# !pip install pygit2==1.15.1 gradio_client

# Clone Fooocus
# %cd /content
if not os.path.exists('/content/Fooocus'):
    # !git clone https://github.com/lllyasviel/Fooocus.git

# %cd /content/Fooocus

# RUN FOOOCUS
# We use --share to get the public URL.
# We explicitly do NOT use --nowebui because we need the Gradio backend active.
print("Starting Fooocus... Wait for the 'Running on public URL' link.")
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 50.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.19.1
#     Uninstalling pygit2-1.19.1:
#       Successfully uninstalled pygit2-1.19.1
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6735, done.
# remote: Total 6735 (delta 0), reused 0 (delta 0), pack-reused 6735 (from 1)
# Receiving objects: 100% (6735/6735), 33.36 MiB | 38.64 MiB/s, done.
# Resolving deltas: 100% (3850/3850), done.
# /content/Fooocus
# Starting Fooocus... Wait for the 'Running on public URL' link.
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# /content/Fooocus/build_launcher.py:9: SyntaxWarning: invalid escape sequence '\p'
#   .\python_embeded\python.exe -s Fooocus\entry_with_update.py {cmds} %*
# Python 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Fooocus version: 2.5.5
# ...

# %%
PLACE THIS IN CTRL SHFT C


function ConnectButton(){
    console.log("Connect pushed");
    document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
}

// Click random elements to simulate activity every 60 seconds
function KeepAlive() {
    console.log("Keep-Alive: Simulating activity...");
    document.querySelector("colab-toolbar-button#connect").click();
}
setInterval(KeepAlive, 60000);

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
